# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ### Importing the Dataset

# %%
data_path = Path("../data/churn_prediction.csv")

# %%
bank_df = pd.read_csv(data_path, header=0)

# %%
bank_df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2101   66   Male         0.0  self_employed   187.0
# 1            2     2348   35   Male         0.0  self_employed     NaN
# 2            4     2194   31   Male         0.0       salaried   146.0
# 3            5     2329   90    NaN         NaN  self_employed  1020.0
# 4            6     1579   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# 1                     2         3214          5390.37  ...
# 2                     2           41          3913.16  ...
# 3                     2          582          2291.91  ...
# 4                     3          388           927.72  ...
#
#    average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                        1458.71                         1449.07
# ...

# %% [markdown]
# ### Viewing the DataSet

# %%
bank_df.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn',
#        'last_transaction'],
#       dtype='object')

# %%
bank_df.tail().transpose()
# Out:
#                                      28377          28378       28379  \
# customer_id                          30297          30298       30299
# vintage                               2325           1537        2376
# age                                     10             34          47
# gender                              Female         Female        Male
# dependents                             0.0            0.0         0.0
# occupation                         student  self_employed    salaried
# city                                1020.0         1046.0      1096.0
# customer_nw_category                     2              2           2
# branch_code                           1207            223         588
# current_balance                    1076.43         3844.1    65511.97
# previous_month_end_balance         1076.43        4069.21    61017.55
# average_monthly_balance_prevQ      2282.19        3668.83    53444.81
# ...

# %%
bank_df["dependents"].value_counts()
# Out:
# dependents
# 0.0     21435
# 2.0      2150
# 1.0      1395
# 3.0       701
# 4.0       179
# 5.0        41
# 6.0         8
# 7.0         3
# 9.0         1
# 52.0        1
# 36.0        1
# 50.0        1
# 8.0         1
# 25.0        1
# 32.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning the Dataset

# %% [markdown]
# Dropping Irrelevant Data

# %%
bank_df.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn',
#        'last_transaction'],
#       dtype='object')

# %%
car_df.drop(['customer_id',], axis = 1, inplace = True)

# %% [markdown]
# ### EDA

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.countplot(x='gender', hue= 'churn', data = bank_df)
plt.subplot(2,2,2)
sns.countplot(x = 'occupation', hue = 'churn', data = bank_df)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 plt.figure(figsize=(10,8))
#       2 plt.subplot(2,2,1)
# ----> 3 sns.countplot(x='gender', hue= 'churn', data = bank_df)
#       4 plt.subplot(2,2,2)
#       5 sns.countplot(x = 'occupation', hue = 'churn', data = bank_df)
#
# File ~/miniconda3/envs/churnGuard/lib/python3.11/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~/miniconda3/envs/churnGuard/lib/python3.11/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
# ...
